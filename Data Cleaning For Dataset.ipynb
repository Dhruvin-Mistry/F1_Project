# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\circuits.csv")
df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
df.drop(columns = 'url',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16140/1866651340.py in <module>
# ----> 1 df.drop(columns = 'url',inplace = True)
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130

# %%
df.dtypes
df['lat'] = round(df['lat'],2)
df['lng'] = round(df['lng'],2)

# %%
df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country    lat     lng  alt
# 0  Australia -37.85  144.97   10
# 1   Malaysia   2.76  101.74   18
# 2    Bahrain  26.03   50.51    7
# 3      Spain  41.57    2.26  109
# 4     Turkey  40.95   29.40  130

# %%
df.to_pickle('circuits_cleaned.csv')

# %%
df2 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\constructor_results.csv")
df2.head()
df2.tail()
df2.drop(columns = 'status',inplace=True)

# %%
df2.head()
df2.to_pickle('constructor_results_cleaned.csv')

# %%
df3 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\constructor_standings.csv")
df3.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
df3.dtypes
df3['positionText'].unique()
# Out:
# array(['1', '3', '2', '4', '5', '6', '8', '7', '9', '10', '11', 'E', '12',
#        '13', '14', '15', '18', '17', '16', '19', '20', '21', '22'],
#       dtype=object)

# %%
df4 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\constructors.csv")
df4.head()
df4.drop(columns='url', inplace = True)

# %%
df4.head()
df4.to_pickle('constructors_cleaned.csv')

# %%
df5 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\drivers.csv")
df5
df5.drop(columns = 'url',inplace=True)

# %%
df5.head()
df5['number'] = df5['number'].replace('\\N',0)
df5['number'].unique()
# Out:
# array(['44', 0, '6', '14', '7', '88', '19', '99', '22', '5', '8', '10',
#        '27', '13', '11', '3', '25', '4', '21', '77', '17', '20', '26',
#        '45', '9', '28', '33', '12', '55', '98', '53', '30', '94', '2',
#        '31', '18', '16', '35', '63', '23', '51', '89', '47', '24', '81'],
#       dtype=object)

# %%
df5['number'] = df5['number'].astype(int)
df5['number'].replace(0,'',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16140/3368031638.py in <module>
# ----> 1 df5['number'] = df5['number'].astype(int)
#       2 df5['number'].replace(0,'',inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
df5.dtypes
# Out:
# driverId        int64
# driverRef      object
# number         object
# code           object
# forename       object
# surname        object
# dob            object
# nationality    object
# dtype: object

# %%
df5['dob'] = pd.to_datetime(df5['dob'])
df5['dob'] = df5['dob'].dt.strftime('%d-%m-%Y')
df5.head()
df5.to_pickle('drivers_cleaned.csv')

# %%
df6 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\races.csv")
df6.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
df6.drop(columns='url',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16308/222721899.py in <module>
# ----> 1 df6.drop(columns='url',inplace=True)
#       2 df6.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df6.head()
df6.replace('\\N',np.nan, inplace=True)
df6.tail()
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 1096    1116  2023     18         69  United States Grand Prix  2023-10-22
# 1097    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 1098    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 1099    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 1100    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26
#
#           time    fp1_date  fp1_time    fp2_date  fp2_time    fp3_date  \
# 1096  19:00:00  2023-10-20  17:30:00  2023-10-21  18:00:00         NaN
# 1097  20:00:00  2023-10-27  18:30:00  2023-10-27  22:00:00  2023-10-28
# 1098  17:00:00  2023-11-03  14:30:00  2023-11-04  14:30:00         NaN
# 1099  06:00:00  2023-11-17  04:30:00  2023-11-17  08:00:00  2023-11-18
# 1100  13:00:00  2023-11-24  09:30:00  2023-11-24  13:00:00  2023-11-25
#
#       fp3_time  quali_date quali_time sprint_date sprint_time
# ...

# %%
df6.dtypes

df6['quali_date'] = pd.to_datetime(df6['quali_date'])
df6['quali_date'] = df6['quali_date'].dt.strftime('%d-%m-%Y')

df6['date'] = pd.to_datetime(df6['date'])
df6['date'] = df6['date'].dt.strftime('%d-%m-%Y')
df6.drop(columns = ['fp1_date','fp1_time','fp2_date','fp2_time','fp3_date','fp3_time'], inplace=True)

# %%
df6.tail()
df6.to_pickle('races_cleaned.csv')

# %%
df7 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\seasons.csv")
df7.head(100)
df7.drop(columns = 'url',inplace=True)

# %%
df7.dtypes
df7.to_pickle('seasons_cleaned.csv')

# %%
df8 = pd.read_csv(r"C:\Users\Dhruvin\Desktop\F1 Project\CSV Files\status.csv")
df8.head(200)
# Out:
#      statusId          status
# 0           1        Finished
# 1           2    Disqualified
# 2           3        Accident
# 3           4       Collision
# 4           5          Engine
# ..        ...             ...
# 134       137          Damage
# 135       138          Debris
# 136       139         Illness
# 137       140       Undertray
# 138       141  Cooling system
#
# [139 rows x 2 columns]
